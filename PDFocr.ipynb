# %%
pip install PyMuPDF opencv-python pytesseract
# Out:
# ...
#      ---------------------------------------- 11.8/11.8 MB 4.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install Pillow numpy
# Out:
#   Cell In[14], line 1
#     pip install Pillow numpy
#         ^
# SyntaxError: invalid syntax

# %%
pip install Flask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import fitz
import pytesseract
import cv2
import io
from PIL import Image  # Import the Image class from the Pillow library
import numpy as np

class PDFOCRApp:
    def __init__(self):
        pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

    def run(self, pdf_path):
        pdf_document = fitz.open('C:\\Users\\lenovo\\Downloads\\KUSHAGRA_SAXENA operations (2) (1).pdf')

        extracted_text = []
        for page_num in range(pdf_document.page_count):
            page = pdf_document[page_num]
            image = page.get_pixmap(matrix=fitz.Matrix(2, 2))
            
            image_bytes = image.samples
            image_pil = Image.frombytes("RGB", [image.width, image.height], image_bytes)
            
            text = self.perform_ocr(image_pil)
            extracted_text.append(text)
        
        pdf_document.close()

        print("Extracted Text:")
        for page_num, text in enumerate(extracted_text, start=1):
            print(f"Page {page_num}:\n{text}\n")

    def perform_ocr(self, image):
        gray = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2GRAY)
        text = pytesseract.image_to_string(gray)
        return text

if __name__ == "__main__":
    app = PDFOCRApp()
    app.run('C:\\Users\\lenovo\\Downloads\\KUSHAGRA_SAXENA operations (2) (1).pdf')
# Out:
# Extracted Text:
# Page 1:
# Kushagra Saxena
#
# kushagrasaxena261@ gmail.com
# +91-7983043767
#
# \ a |
#
# CAREER OBJECTIVE
#
# Seeking position as Team Lead with company that allows for career advancement through utilization of
#
# leadership, administrative and communication skills for mutual growth and success.
#
# CORE COMPETENCIES
#
# Worked for German banks and handled many teams like AML,KYC ,Account opening,
# Customer information system and Change of address and having a in-depth knowledge of
# banking operations and team which I was handling.
#
# Operation and Team Management
# Manage a team of 30 FTE's Client/Customer/People Management
#
# Drive Performance in the team to meet targets
#
# Manage the daily team activities and ensure the daily operations run smoothly.
#
# Drive Team adherence and manage monthly scheduling. Handle customer escalations
#
# Manage key business metrics and SLA's.
#
# Drive Continuous Improvement in the team along with metrics improvement
#
# ...
